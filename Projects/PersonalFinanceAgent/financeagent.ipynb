# %% [markdown]
# ## Building a Personal Finance Agent using Strands

# %% [markdown]
# A Basic Personal finance Agent which will perform budget analysis and aid you in personal finance, create tools that the Agent can use, add memory and integrate Amazon Bedrock Guardrails to add safety filters to the LLM outputs and inputs to the Agent.

# %% [markdown]
#  uv add strands-agents strands-agents-tools matplotlib pandas tabulate

# %%
from strands import Agent
from strands.models import BedrockModel

import warnings

print (" Strands Agent SDK imported successfully! ")
# Out:
#  Strands Agent SDK imported successfully!

# %%
model = BedrockModel(
    model_id="meta.llama3-2-3b-instruct-v1:0"
    # This connects to your AWS Bedrock service
)

print("AWS Bedrock model configured for Strands!")
print("Ready to build first agent")
# Out:
# AWS Bedrock model configured for Strands!
# Ready to build first agent

# %% [markdown]
# ## Step 2: Creating First Strands Agent
#
# Core Strands Pattern: Agent(model=model)

# %%
basic_agent = Agent(model=model)

# %%
# Test your first Strands agent

response = basic_agent("What is the 50/30/20 budgeting rule? ")
print(response)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Test your first Strands agent
#       2
# ----> 3 response = basic_agent("What is the 50/30/20 budgeting rule? ")
#       4 print(response)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\agent.py:814, in Agent.__call__(self, prompt, invocation_state, structured_output_model, structured_output_prompt, idempotency_token, limits, **kwargs)
#     757 def __call__(
#     758     self,
#     759     prompt: AgentInput = None,
#    (...)    766     **kwargs: Any,
#     767 ) -> AgentResult:
#     768     """Process a natural language prompt through the agent's event loop.
#     769
#     770     This method implements the conversational interface with multiple input patterns:
#    (...)    812         Exception: Any exceptions from the agent invocation will be propagated to the caller.
#     813     """
# --> 814     return run_async(
#     815         lambda: self._invoke_async_and_flush(
#     816             prompt,
#     817             invocation_state=invocation_state,
#     818             structured_output_model=structured_output_model,
#     819             structured_output_prompt=structured_output_prompt,
#     820             idempotency_token=idempotency_token,
#     821             limits=limits,
#     822             **kwargs,
#     823         )
#     824     )
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\_async.py:34, in run_async(async_func)
#      32 context = contextvars.copy_context()
#      33 future = executor.submit(context.run, execute)
# ---> 34 return future.result()
#
# File C:\Program Files\Python313\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File C:\Program Files\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\Program Files\Python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:161, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     159 try:
#     160     token = context.attach(otel_context)
# --> 161     return original_func(*func_args, **func_kwargs)
#     162 finally:
#     163     if token is not None:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\_async.py:29, in run_async.<locals>.execute()
#      28 def execute() -> T:
# ---> 29     return asyncio.run(execute_async())
#
# File C:\Program Files\Python313\Lib\asyncio\runners.py:195, in run(main, debug, loop_factory)
#     191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 195     return runner.run(main)
#
# File C:\Program Files\Python313\Lib\asyncio\runners.py:118, in Runner.run(self, coro, context)
#     116 self._interrupt_count = 0
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#     120     if self._interrupt_count > 0:
#
# File C:\Program Files\Python313\Lib\asyncio\base_events.py:725, in BaseEventLoop.run_until_complete(self, future)
#     722 if not future.done():
#     723     raise RuntimeError('Event loop stopped before Future completed.')
# --> 725 return future.result()
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\_async.py:26, in run_async.<locals>.execute_async()
#      25 async def execute_async() -> T:
# ---> 26     return await async_func()
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\agent.py:834, in Agent._invoke_async_and_flush(self, prompt, **kwargs)
#     827 """Run ``invoke_async`` then flush the memory manager within this loop.
#     828
#     829 The synchronous entry point runs each invocation in its own event loop, which would
#     830 cancel background extraction saves on close. Flushing here persists them. The async
#     831 path does not flush, leaving extraction on its trigger cadence.
#     832 """
#     833 try:
# --> 834     return await self.invoke_async(prompt, **kwargs)
#     835 finally:
#     836     if self.memory_manager is not None:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\agent.py:904, in Agent.invoke_async(self, prompt, invocation_state, structured_output_model, structured_output_prompt, idempotency_token, limits, **kwargs)
#     850 """Process a natural language prompt through the agent's event loop.
#     851
#     852 This method implements the conversational interface with multiple input patterns:
#    (...)    893     Exception: Any exceptions from the agent invocation will be propagated to the caller.
#     894 """
#     895 events = self.stream_async(
#     896     prompt,
#     897     invocation_state=invocation_state,
#    (...)    902     **kwargs,
#     903 )
# --> 904 async for event in events:
#     905     _ = event
#     907 return cast(AgentResult, event["result"])
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\agent.py:1269, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, structured_output_prompt, idempotency_token, limits, **kwargs)
#    1266 # The result is the last EventLoopStopEvent, not the last event overall:
#    1267 # AgentStreamStage middleware may yield trailing events after the stop event.
#    1268 stop_event: EventLoopStopEvent | None = None
# -> 1269 async for event in events:
#    1270     event.prepare(invocation_state=merged_state)
#    1272     if isinstance(event, EventLoopStopEvent):
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\agent.py:1380, in Agent._run_loop(self, messages, invocation_state, structured_output_model, structured_output_prompt, limits)
#    1370 middleware_context = AgentStreamContext(
#    1371     agent=self,
#    1372     messages=current_messages,
#    (...)   1377     _interrupts=dict(self._interrupt_state.interrupts) if self._interrupt_state.activated else {},
#    1378 )
#    1379 try:
# -> 1380     async for event in self._middleware_registry.invoke(
#    1381         AgentStreamStage,
#    1382         middleware_context,
#    1383         self._make_agent_stream_terminal(structured_output_context, limits, pass_progress),
#    1384     ):
#    1385         if isinstance(event, EventLoopStopEvent):
#    1386             agent_result = AgentResult(*event["stop"])
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\_middleware\registry.py:167, in MiddlewareRegistry.invoke(self, stage, context, terminal)
#     165 gen = chain(context)
#     166 try:
# --> 167     async for event in gen:
#     168         yield event
#     169 finally:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\_middleware\registry.py:144, in MiddlewareRegistry.compose.<locals>._make_layer.<locals>.layer(ctx)
#     142 handler_gen = h(ctx, tracking_next)
#     143 try:
# --> 144     async for event in handler_gen:
#     145         yield event
#     146 finally:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\_agent_delegation.py:319, in AgentDelegation._handle_stream(self, context, next_fn)
#     316 buffering = False
#     318 try:
# --> 319     async for event in next_fn(context):
#     320         if buffering:
#     321             tail_buffer.append(event)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\agent.py:1487, in Agent._make_agent_stream_terminal.<locals>.terminal(ctx)
#    1484 async def terminal(ctx: "AgentStreamContext") -> AsyncGenerator[TypedEvent, None]:
#    1485     # Execute the event loop cycle with retry logic for context limits
#    1486     events = self._execute_event_loop_cycle(ctx.invocation_state, structured_output_context, limits)
# -> 1487     async for event in events:
#    1488         if isinstance(event, EventLoopStopEvent):
#    1489             pass_progress.event_loop_produced_result = True
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\agent\agent.py:1542, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context, limits)
#    1535 try:
#    1536     events = event_loop_cycle(
#    1537         agent=self,
#    1538         invocation_state=invocation_state,
#    1539         structured_output_context=structured_output_context,
#    1540         limits=limits,
#    1541     )
# -> 1542     async for event in events:
#    1543         yield event
#    1545 except ContextWindowOverflowException as e:
#    1546     # Try reducing the context size and retrying
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\event_loop\event_loop.py:298, in event_loop_cycle(agent, invocation_state, structured_output_context, limits)
#     294 else:
#     295     model_events = _handle_model_execution(
#     296         agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     297     )
# --> 298     async for model_event in model_events:
#     299         if not isinstance(model_event, ModelStopReason):
#     300             yield model_event
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\event_loop\event_loop.py:641, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     639         # No retry requested, raise the exception
#     640         yield ForceStopEvent(reason=e)
# --> 641         raise e
#     643 try:
#     644     # Add message in trace and mark the end of the stream messages trace
#     645     stream_trace.add_message(message)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\event_loop\event_loop.py:561, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     558 # Run through middleware chain. The last yielded event is ModelStopReason
#     559 # which serves as both the streaming result event and the middleware result.
#     560 last_event = None
# --> 561 async for event in agent._middleware_registry.invoke(
#     562     InvokeModelStage,
#     563     middleware_context,
#     564     _make_invoke_model_terminal(agent, cycle_span, tracer, model_state_snapshot),
#     565 ):
#     566     last_event = event
#     567     yield event
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\_middleware\registry.py:167, in MiddlewareRegistry.invoke(self, stage, context, terminal)
#     165 gen = chain(context)
#     166 try:
# --> 167     async for event in gen:
#     168         yield event
#     169 finally:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\event_loop\event_loop.py:686, in _make_invoke_model_terminal.<locals>.terminal(ctx)
#     684 with trace_api.use_span(model_invoke_span, end_on_exit=False):
#     685     try:
# --> 686         async for event in stream_messages(
#     687             ctx.model,
#     688             system_prompt_str,
#     689             ctx.messages,
#     690             ctx.tool_specs,
#     691             system_prompt_content=system_prompt_content,
#     692             tool_choice=ctx.tool_choice,
#     693             invocation_state=ctx.invocation_state,
#     694             model_state=model_state,
#     695             dynamic_trailing_blocks=ctx.dynamic_trailing_blocks,
#     696             cancel_signal=agent._cancel_signal,
#     697         ):
#     698             yield event
#     700         stop_reason, message, usage, metrics = event["stop"]
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\event_loop\streaming.py:543, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice, system_prompt_content, invocation_state, model_state, dynamic_trailing_blocks, cancel_signal, **kwargs)
#     529 start_time = time.time()
#     531 chunks = model.stream(
#     532     messages,
#     533     tool_specs if tool_specs else None,
#    (...)    540     **({"dynamic_trailing_blocks": dynamic_trailing_blocks} if dynamic_trailing_blocks else {}),
#     541 )
# --> 543 async for event in process_stream(chunks, start_time, cancel_signal):
#     544     yield event
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\event_loop\streaming.py:448, in process_stream(chunks, start_time, cancel_signal)
#     445 usage: Usage = Usage(inputTokens=0, outputTokens=0, totalTokens=0)
#     446 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 448 async for chunk in chunks:
#     449     # Check for cancellation during stream processing
#     450     if cancel_signal and cancel_signal.is_set():
#     451         logger.debug("cancellation detected during stream processing")
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\models\bedrock.py:1264, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, system_prompt_content, **kwargs)
#    1261             break
#    1263         yield event
# -> 1264     await task
#    1265 except BaseException:
#    1266     task.add_done_callback(_suppress_task_exception)
#
# File C:\Program Files\Python313\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File C:\Program Files\Python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:161, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     159 try:
#     160     token = context.attach(otel_context)
# --> 161     return original_func(*func_args, **func_kwargs)
#     162 finally:
#     163     if token is not None:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\strands\models\bedrock.py:1309, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice, dynamic_trailing_blocks)
#    1306 converse_method = self.client.converse_stream if streaming else self.client.converse
#    1308 try:
# -> 1309     response = converse_method(**request)
#    1310 except ClientError as error:
#    1311     error_details = error.response.get("Error", {})
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\client.py:1076, in BaseClient._make_api_call(self, operation_name, api_params)
#    1072     maybe_compress_request(
#    1073         self.meta.config, request_dict, operation_model
#    1074     )
#    1075     apply_request_checksum(request_dict)
# -> 1076     http, parsed_response = self._make_request(
#    1077         operation_model, request_dict, request_context
#    1078     )
#    1080 self.meta.events.emit(
#    1081     f'after-call.{service_id}.{operation_name}',
#    1082     http_response=http,
#    (...)   1085     context=request_context,
#    1086 )
#    1088 if http.status_code >= 300:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\client.py:1100, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1098 def _make_request(self, operation_model, request_dict, request_context):
#    1099     try:
# -> 1100         return self._endpoint.make_request(operation_model, request_dict)
#    1101     except Exception as e:
#    1102         self.meta.events.emit(
#    1103             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1104             exception=e,
#    1105             context=request_context,
#    1106         )
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\endpoint.py:198, in Endpoint._send_request(self, request_dict, operation_model)
#     196 context = request_dict['context']
#     197 self._update_retries_context(context, attempts)
# --> 198 request = self.create_request(request_dict, operation_model)
#     199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)    207     exception,
#     208 ):
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\endpoint.py:132, in Endpoint.create_request(self, params, operation_model)
#     130     service_id = operation_model.service_model.service_id.hyphenize()
#     131     event_name = f'request-created.{service_id}.{operation_model.name}'
# --> 132     self._event_emitter.emit(
#     133         event_name,
#     134         request=request,
#     135         operation_name=operation_model.name,
#     136     )
#     137 prepared_request = self.prepare_request(request)
#     138 return prepared_request
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)    254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\signers.py:108, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     103 def handler(self, operation_name=None, request=None, **kwargs):
#     104     # This is typically hooked up to the "request-created" event
#     105     # from a client's event emitter.  When a new request is created
#     106     # this method is invoked to sign the request.
#     107     # Don't call this method directly.
# --> 108     return self.sign(operation_name, request)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\signers.py:200, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     197     else:
#     198         raise e
# --> 200 auth.add_auth(request)
#
# File c:\100DaysOfAI\.venv\Lib\site-packages\botocore\auth.py:429, in SigV4Auth.add_auth(self, request)
#     427 def add_auth(self, request):
#     428     if self.credentials is None:
# --> 429         raise NoCredentialsError()
#     430     datetime_now = get_current_datetime()
#     431     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
