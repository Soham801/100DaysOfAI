# %% [markdown]
# Langchain Version V1

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.agents import create_agent




agent=create_agent(
    model="gemini-2.5-flash",
    tools=[],
    system_prompt="You are a help assistant."
)
agent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.agents import create_agent
#       2
#       3
#       4
#
# File c:\100DaysOfAI\langchainupdated\.venv\Lib\site-packages\langchain\agents\__init__.py:3
#       1 """Entrypoint to building [Agents](https://docs.langchain.com/oss/python/langchain/agents) with LangChain."""  # noqa: E501
# ----> 3 from langchain.agents.factory import create_agent
#       4 from langchain.agents.middleware.types import AgentState
#       6 __all__ = [
#       7     "AgentState",
#       8     "create_agent",
#       9 ]
#
# File c:\100DaysOfAI\langchainupdated\.venv\Lib\site-packages\langchain\agents\factory.py:19
#       7 from dataclasses import dataclass, field, fields
#       8 from typing import (
#       9     TYPE_CHECKING,
#      10     Annotated,
#    (...)     16     get_type_hints,
#      17 )
# ---> 19 from langchain_core.language_models.chat_models import BaseChatModel
#      20 from langchain_core.messages import AIMessage, AnyMessage, SystemMessage, ToolMessage
#      21 from langchain_core.tools import BaseTool
#
# File c:\100DaysOfAI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:40
#      29 from langchain_core.language_models._compat_bridge import (
#      30     achunks_to_events,
#      31     amessage_to_events,
#      32     chunks_to_events,
#      33     message_to_events,
#      34 )
#      35 from langchain_core.language_models._utils import (
#      36     _filter_invocation_params_for_tracing,
#      37     _normalize_messages,
#      38     _update_message_content_to_blocks,
#      39 )
# ---> 40 from langchain_core.language_models.base import (
#      41     BaseLanguageModel,
#      42     LangSmithParams,
#      43     LanguageModelInput,
#      44 )
#      45 from langchain_core.language_models.chat_model_stream import (
#      46     AsyncChatModelStream,
#      47     ChatModelStream,
#      48 )
#      49 from langchain_core.language_models.model_profile import (
#      50     ModelProfile,
#      51     _warn_unknown_profile_keys,
#      52 )
#
# File c:\100DaysOfAI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\base.py:36
#      24 from langchain_core.messages import (
#      25     AIMessage,
#      26     AnyMessage,
#    (...)     29     get_buffer_string,
#      30 )
#      31 from langchain_core.prompt_values import (
#      32     ChatPromptValueConcrete,
#      33     PromptValue,
#      34     StringPromptValue,
#      35 )
# ---> 36 from langchain_core.runnables import Runnable, RunnableSerializable
#      38 if TYPE_CHECKING:
#      39     from langchain_core.outputs import LLMResult
#
# File c:\100DaysOfAI\langchainupdated\.venv\Lib\site-packages\langchain_core\runnables\__init__.py:130, in __getattr__(attr_name)
#     128 def __getattr__(attr_name: str) -> object:
#     129     module_name = _dynamic_imports.get(attr_name)
# --> 130     result = import_attr(attr_name, module_name, __spec__.parent)
#     131     globals()[attr_name] = result
#     132     return result
#
# File c:\100DaysOfAI\langchainupdated\.venv\Lib\site-packages\langchain_core\_import_utils.py:39, in import_attr(attr_name, module_name, package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
# ---> 39         raise ImportError(msg) from None
#      40     result = getattr(module, attr_name)
#      41 return result
#
# ImportError: module ''langchain_core.runnables'.'base'' not found (No module named 'jsonpatch')
