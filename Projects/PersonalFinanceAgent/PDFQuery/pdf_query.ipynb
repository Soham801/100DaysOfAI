# %% [markdown]
# ## PDF Document Question Answering LLM system with Langchain , Cassandra , AstraDB

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\100DaysOfAI\.venv\Scripts\python.exe: No module named uv
